# %%
import sys
from pathlib import Path

# notebook = src/notebooks/chat_rag.ipynb
# on remonte d'un niveau -> src
PROJECT_SRC = Path.cwd().parent

if str(PROJECT_SRC) not in sys.path:
    sys.path.append(str(PROJECT_SRC))

print("PATH OK:", PROJECT_SRC)
# Out:
# PATH OK: /Users/hanafkiri/Documents/supplychain-agent/src

# %%
from Retrieval.vector_store import InMemoryVectorStore
from Retrieval.ingest import ingest_documents
from retrieval.retriever import Retriever

from LLM.openai_client import OpenAIClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 from retrieval.vector_store import InMemoryVectorStore
#       2 from retrieval.ingest import ingest_documents
#       3 from retrieval.retriever import Retriever
#
# ModuleNotFoundError: No module named 'retrieval'
